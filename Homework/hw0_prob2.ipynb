# %%
import networkx as nx
import matplotlib.pyplot as plt

N = 500
p = 0.016
G1 = nx.erdos_renyi_graph(N, p)

pos = nx.spring_layout(G1)
nx.draw(G1, pos, node_color='red', with_labels=False, node_size=30)
plt.axis('off')
plt.show()
